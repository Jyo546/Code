# %%
import pandas as pd

# Load the dataset
data = pd.read_csv(r"C:\Users\K.NAGI REDDY\OneDrive\Desktop\DATASETSgenerated_dataset.csv")

# %%
# Display the first few rows of the dataset
print(data.head())
# Out:
#    tweet_id                                           text           source  \
# 0         1    Just discovered a new species of butterfly!          Twitter
# 1         2  COVID-19 update: Cases are on the rise again.     Online Forum
# 2         3               Just saw a UFO in my backyard! 👽     Online Forum
# 3         4  COVID-19 update: Cases are on the rise again.  Gossip Magazine
# 4         5        New tech gadget just released! #excited    Tech Magazine
#
#    user_id sentiment          topic  rumor_label
# 0   311160   Neutral            UFO         True
# 1   434641   Neutral        Animals        False
# 2   970264  Negative  Cybersecurity        False
# 3   169653  Negative           Tech        False
# 4   845759  Positive        Animals         True

# %%
# Summary statistics for numerical columns
print(data.describe())
# Out:
#           tweet_id        user_id
# count  2000.000000    2000.000000
# mean   1000.500000  555669.948500
# std     577.494589  261432.844091
# min       1.000000  100816.000000
# 25%     500.750000  326558.750000
# 50%    1000.500000  570017.500000
# 75%    1500.250000  779507.000000
# max    2000.000000  999137.000000

# %%
# Data types and missing values
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tweet_id     2000 non-null   int64
#  1   text         2000 non-null   object
#  2   source       2000 non-null   object
#  3   user_id      2000 non-null   int64
#  4   sentiment    2000 non-null   object
#  5   topic        2000 non-null   object
#  6   rumor_label  2000 non-null   bool
# dtypes: bool(1), int64(2), object(4)
# memory usage: 95.8+ KB
# None

# %%
# Distribution of categorical variables
print(data['sentiment'].value_counts())
print(data['topic'].value_counts())
print(data['source'].value_counts())
# Out:
# sentiment
# Negative    673
# Neutral     667
# Positive    660
# Name: count, dtype: int64
# topic
# Discovery        211
# Health           209
# Conspiracy       183
# UFO              180
# COVID-19         178
# Cybersecurity    177
# Tech             175
# Community        175
# Weather          175
# Animals          169
# Celebrity        168
# Name: count, dtype: int64
# source
# Health Magazine    243
# Twitter            237
# Social Media       233
# Gossip Magazine    232
# Government         226
# News               220
# Online Forum       206
# Science Journal    205
# Tech Magazine      198
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of sentiments
sns.countplot(data=data, x='sentiment')
plt.title('Distribution of Sentiments')
plt.show()

# Distribution of topics
plt.figure(figsize=(10, 6))
sns.countplot(data=data, y='topic')
plt.title('Distribution of Topics')
plt.show()

# Distribution of sources
plt.figure(figsize=(8, 6))
sns.countplot(data=data, y='source')
plt.title('Distribution of Sources')
plt.show()

# %%
import numpy as np
# Select only numeric columns for correlation calculation
numeric_data = data.select_dtypes(include=np.number)

# Calculate correlation matrix
correlation_matrix = numeric_data.corr()
print(correlation_matrix)
# Out:
#           tweet_id   user_id
# tweet_id  1.000000 -0.028998
# user_id  -0.028998  1.000000

# %%
# !pip install wordcloud
# Text analysis
average_text_length = data['text'].apply(len).mean()
print("Average length of text:", average_text_length)

# Word cloud
from wordcloud import WordCloud

text = ' '.join(data['text'].values)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Tweets')
plt.show()
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/300.2 kB 187.9 kB/s eta 0:00:02
#    --- ----------------------------------- 30.7/300.2 kB 187.9 kB/s eta 0:00:02
#    --------- ----------------------------- 71.7/300.2 kB 281.8 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/300.2 kB 281.8 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/300.2 kB 281.8 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/300.2 kB 281.8 kB/s eta 0:00:01
#    --------------- ---------------------- 122.9/300.2 kB 267.6 kB/s eta 0:00:01
#    ---------------------- --------------- 174.1/300.2 kB 389.2 kB/s eta 0:00:01
#    ---------------------- --------------- 174.1/300.2 kB 389.2 kB/s eta 0:00:01
#    ---------------------- --------------- 174.1/300.2 kB 389.2 kB/s eta 0:00:01
#    ---------------------- --------------- 174.1/300.2 kB 389.2 kB/s eta 0:00:01
#    -------------------------------------- 300.2/300.2 kB 453.0 kB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Average length of text: 42.4535

# %%
average_text_length = data['text'].apply(len).mean()
print("Average length of text:", average_text_length)

# Word cloud
from wordcloud import WordCloud

text = ' '.join(data['text'].values)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Tweets')
plt.show()
# Out:
# Average length of text: 42.4535

# %%
text = text.lower()

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\K.NAGI
# [nltk_data]     REDDY\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)

# %%
import string

# Define punctuation marks
punctuation = string.punctuation

# Remove punctuation marks
tokens = [token for token in tokens if token not in punctuation]

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\K.NAGI
# [nltk_data]     REDDY\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# Load stopwords
stop_words = set(stopwords.words('english'))

# Remove stopwords
tokens = [token for token in tokens if token not in stop_words]

# %%
import nltk

nltk.download('wordnet')
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# Initialize stemmer and lemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Stemming
stemmed_tokens = [stemmer.stem(token) for token in tokens]

# Lemmatization
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\K.NAGI
# [nltk_data]     REDDY\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
processed_text = ' '.join(tokens)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Assuming 'processed_text' contains a list of preprocessed text documents

# Initialize the TfidfVectorizer
vectorizer = TfidfVectorizer()

# Fit and transform the processed text data
tfidf_matrix = vectorizer.fit_transform([processed_text])  # Ensure processed_text is wrapped in a list

# %%
data['text_length'] = data['text'].apply(len)

# %%
data['word_count'] = data['text'].apply(lambda x: len(x.split()))

# %%
data['char_count'] = data['text'].apply(lambda x: len(x.replace(" ", "")))

# %%
data['has_hashtag'] = data['text'].apply(lambda x: 1 if '#' in x else 0)
data['has_mention'] = data['text'].apply(lambda x: 1 if '@' in x else 0)

# %%
# !pip install textblob
from textblob import TextBlob

data['sentiment_score'] = data['text'].apply(lambda x: TextBlob(x).sentiment.polarity)
# Out:
# Collecting textblob
#   Obtaining dependency information for textblob from https://files.pythonhosted.org/packages/02/07/5fd2945356dd839974d3a25de8a142dc37293c21315729a41e775b5f3569/textblob-0.18.0.post0-py3-none-any.whl.metadata
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: nltk>=3.8 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\k.nagi reddy\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    -- ------------------------------------- 41.0/626.3 kB ? eta -:--:--
#    -- ------------------------------------- 41.0/626.3 kB ? eta -:--:--
#    --- ----------------------------------- 61.4/626.3 kB 465.5 kB/s eta 0:00:02
#    ---- ---------------------------------- 71.7/626.3 kB 357.2 kB/s eta 0:00:02
#    ---- ---------------------------------- 71.7/626.3 kB 357.2 kB/s eta 0:00:02
#    ---- ---------------------------------- 71.7/626.3 kB 357.2 kB/s eta 0:00:02
#    ------ ------------------------------- 112.6/626.3 kB 327.2 kB/s eta 0:00:02
#    ------ ------------------------------- 112.6/626.3 kB 327.2 kB/s eta 0:00:02
#    ------ ------------------------------- 112.6/626.3 kB 327.2 kB/s eta 0:00:02
#    ------ ------------------------------- 112.6/626.3 kB 327.2 kB/s eta 0:00:02
#    --------- ---------------------------- 153.6/626.3 kB 286.7 kB/s eta 0:00:02
#    --------- ---------------------------- 153.6/626.3 kB 286.7 kB/s eta 0:00:02
#    --------- ---------------------------- 153.6/626.3 kB 286.7 kB/s eta 0:00:02
#    --------- ---------------------------- 153.6/626.3 kB 286.7 kB/s eta 0:00:02
#    --------- ---------------------------- 153.6/626.3 kB 286.7 kB/s eta 0:00:02
#    --------- ---------------------------- 153.6/626.3 kB 286.7 kB/s eta 0:00:02
#    --------- ---------------------------- 153.6/626.3 kB 286.7 kB/s eta 0:00:02
#    ----------- -------------------------- 194.6/626.3 kB 222.6 kB/s eta 0:00:02
#    ----------- -------------------------- 194.6/626.3 kB 222.6 kB/s eta 0:00:02
#    ------------ ------------------------- 204.8/626.3 kB 211.0 kB/s eta 0:00:02
#    ------------------------------------ - 593.9/626.3 kB 135.8 kB/s eta 0:00:01
#    ------------------------------------ - 593.9/626.3 kB 135.8 kB/s eta 0:00:01
#    -------------------------------------  614.4/626.3 kB 137.1 kB/s eta 0:00:01
#    -------------------------------------  614.4/626.3 kB 137.1 kB/s eta 0:00:01
#    -------------------------------------  614.4/626.3 kB 137.1 kB/s eta 0:00:01
#    -------------------------------------  614.4/626.3 kB 137.1 kB/s eta 0:00:01
#    -------------------------------------- 626.3/626.3 kB 133.2 kB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.18.0.post0

# %%
from textblob import TextBlob

# Assuming 'data' DataFrame contains a column named 'text' with text data

# Calculate sentiment scores
data['sentiment_score'] = data['text'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\K.NAGI REDDY\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
import nltk

def pos_tag(text):
    tokens = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    return pos_tags

data['pos_tags'] = data['text'].apply(pos_tag)

# %%
topics = ['Health', 'UFO', 'COVID-19', 'Tech', 'Conspiracy']
for topic in topics:
    data[f'has_{topic.lower()}'] = data['topic'].apply(lambda x: 1 if x == topic else 0)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='rumor_label', data=data)
plt.title('Distribution of Rumor Labels')
plt.xlabel('Rumor Label')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='sentiment', hue='rumor_label', data=data)
plt.title('Sentiment Distribution by Rumor Label')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.legend(title='Rumor Label')
plt.show()

# %%
text_source_counts = data['source'].value_counts()
plt.figure(figsize=(8, 6))
text_source_counts.plot(kind='bar', color='skyblue')
plt.title('Count of Text Sources')
plt.xlabel('Text Source')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
text_source_counts = data['source'].value_counts()
plt.figure(figsize=(8, 6))
text_source_counts.plot(kind='pie',autopct='%1.1f%%')
plt.title('Count of Text Sources')
plt.show()

# %%
text_source_counts = data['topic'].value_counts()
plt.figure(figsize=(15, 6))
text_source_counts.plot(kind='bar', color='skyblue')
plt.title('Count of Topics')
plt.xlabel('Topic')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
X = data['text']
y = data['rumor_label']

# %%
print(X,"\n\n\n",y)
# Out:
# 0             Just discovered a new species of butterfly!
# 1           COVID-19 update: Cases are on the rise again.
# 2                        Just saw a UFO in my backyard! 👽
# 3           COVID-19 update: Cases are on the rise again.
# 4                 New tech gadget just released! #excited
#                               ...
# 1995      Weather forecast: Expect rain showers tomorrow.
# 1996          Just discovered a new species of butterfly!
# 1997    Protect your data with the latest cybersecurit...
# 1998     Celebrity gossip: What's happening in Hollywood?
# 1999                     Just saw a UFO in my backyard! 👽
# Name: text, Length: 2000, dtype: object
#
#
#  0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1995    False
# 1996     True
# 1997    False
# 1998    False
# 1999     True
# Name: rumor_label, Length: 2000, dtype: bool

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# %%
X_vectorized
# Out:
# <2000x60 sparse matrix of type '<class 'numpy.float64'>'
# 	with 12318 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVC

clf = SVC()

# %%
import warnings
from sklearn.svm import SVC

# Suppress FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning)

# Instantiate SVC with default parameters
clf = SVC()
from sklearn.metrics import accuracy_score,classification_report

from sklearn.svm import LinearSVC

S_classifier = LinearSVC()
S_classifier.fit(X_train, y_train)
y_pred = S_classifier.predict(X_test)
svm_accuracy = accuracy_score(y_test, y_pred)*100

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.75      0.59       190
#         True       0.55      0.28      0.37       210
#
#     accuracy                           0.50       400
#    macro avg       0.52      0.51      0.48       400
# weighted avg       0.52      0.50      0.47       400

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)
rf_y_pred = rf_classifier.predict(X_test)
rf_accuracy = accuracy_score(y_test, rf_y_pred)*100

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.75      0.59       190
#         True       0.55      0.28      0.37       210
#
#     accuracy                           0.50       400
#    macro avg       0.52      0.51      0.48       400
# weighted avg       0.52      0.50      0.47       400

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)
knn_y_pred = knn_classifier.predict(X_test)
knn_accuracy = accuracy_score(y_test, knn_y_pred)*100

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.75      0.59       190
#         True       0.55      0.28      0.37       210
#
#     accuracy                           0.50       400
#    macro avg       0.52      0.51      0.48       400
# weighted avg       0.52      0.50      0.47       400

# %%
from sklearn.tree import DecisionTreeClassifier

dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train, y_train)
dt_y_pred = dt_classifier.predict(X_test)
dt_accuracy = accuracy_score(y_test, dt_y_pred)*100

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.75      0.59       190
#         True       0.55      0.28      0.37       210
#
#     accuracy                           0.50       400
#    macro avg       0.52      0.51      0.48       400
# weighted avg       0.52      0.50      0.47       400

# %%
models = ['LinearSVC', 'Random Forest', 'KNN', 'Decision Tree']
accuracies = [svm_accuracy, rf_accuracy, knn_accuracy, dt_accuracy]

plt.figure(figsize=(10, 6))
plt.bar(models, accuracies, color=['blue', 'green', 'orange', 'red'])
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy of Different Classification Models')
plt.ylim(0, 100)
plt.show()

best_model_index = accuracies.index(max(accuracies))
best_model = models[best_model_index]
print(f"The best model is '{best_model}' with an accuracy of {max(accuracies)}")
# Out:
# The best model is 'Random Forest' with an accuracy of 52.25

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier

# Create a RandomForestClassifier instance
classifier = RandomForestClassifier()

# Fit the classifier to your training data
classifier.fit(X_train, y_train)

# Now you can make predictions
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, xticklabels=['True', 'False'], yticklabels=['True', 'False'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
example_text = [input("enter rumor : ")]
example_text_vectorized = vectorizer.transform(example_text)
prediction = classifier.predict(example_text_vectorized)
print("Example prediction:", prediction)
# Out:
# enter rumor : covid
# Example prediction: [False]
